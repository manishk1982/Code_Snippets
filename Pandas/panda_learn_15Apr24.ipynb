# %%
import pandas as pd

# %%
df = pd.read_csv("./pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.tail(4)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df_xls = pd.read_excel("pokemon_data.xlsx")

# %%
df_xls
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # df_txt = pd.read_csv("pokemon_data.txt")
# df_txt = pd.read_csv("pokemon_data.txt", delimiter=" ")
# df_txt

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.columns[1:]
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name'][-4:]
# Out:
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, dtype: object

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.Name[-1:]
# Out:
# 799    Volcanion
# Name: Name, dtype: object

# %%
df[['Name', 'HP', 'Type 1']]
# Out:
#                       Name  HP   Type 1
# 0                Bulbasaur  45    Grass
# 1                  Ivysaur  60    Grass
# 2                 Venusaur  80    Grass
# 3    VenusaurMega Venusaur  80    Grass
# 4               Charmander  39     Fire
# ..                     ...  ..      ...
# 795                Diancie  50     Rock
# 796    DiancieMega Diancie  50     Rock
# 797    HoopaHoopa Confined  80  Psychic
# 798     HoopaHoopa Unbound  80  Psychic
# 799              Volcanion  80     Fire
#
# [800 rows x 3 columns]

# %%
df[['Name', 'HP', 'Type 1']][:5]
# Out:
#                     Name  HP Type 1
# 0              Bulbasaur  45  Grass
# 1                Ivysaur  60  Grass
# 2               Venusaur  80  Grass
# 3  VenusaurMega Venusaur  80  Grass
# 4             Charmander  39   Fire

# %%
df.iloc[4]
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
df.iloc[:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[2,3]
# Out:
# 'Poison'

# %%
df.iloc[4,3]
# Out:
# nan

# %%
df.iloc[4,1]
# Out:
# 'Charmander'

# %%
df.iloc[3,1]
# Out:
# 'VenusaurMega Venusaur'

# %%
df.iloc[2,3]
# Out:
# 'Poison'

# %%
df.iloc[0:2, 0:4]
# Out:
#    #       Name Type 1  Type 2
# 0  1  Bulbasaur  Grass  Poison
# 1  2    Ivysaur  Grass  Poison

# %%
df.loc[df['HP'] > 198]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113  Chansey  Normal    NaN  250       5        5       35      105
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False

# %%
df.loc[df['HP'] > 98 and df['Attack'] < 20]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22188\311127857.py in ?()
# ----> 1 df.loc[df['HP'] > 98 and df['Attack'] < 20]
#
# C:\Program Files\Python311\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'HP'])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'HP'], ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'HP'], ascending=[False, True])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'HP'], ascending=[0, 1])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total'] = 0

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False      0
# ...

# %%
df['Total'] = df['HP'] + df['Attack']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False     94
# ...

# %%
df.iloc[:, 4:10]
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %%
#sum(df.iloc[:, 4:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 sum(df.iloc[:, 4:10])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False     94
# ...

# %%
df = df.drop(columns=['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.drop(columns=['Attack', 'HP'])
# Out:
#        #                   Name   Type 1  Type 2  Defense  Sp. Atk  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison       49       65       65
# 1      2                Ivysaur    Grass  Poison       63       80       80
# 2      3               Venusaur    Grass  Poison       83      100      100
# 3      3  VenusaurMega Venusaur    Grass  Poison      123      122      120
# 4      4             Charmander     Fire     NaN       43       60       50
# ..   ...                    ...      ...     ...      ...      ...      ...
# 795  719                Diancie     Rock   Fairy      150      100      150
# 796  719    DiancieMega Diancie     Rock   Fairy      110      160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost       60      150      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark       60      170      130
# 799  721              Volcanion     Fire   Water      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
#sum(df.iloc[:, 4:10])
df.iloc[:, 4:10].sum()
# Out:
# HP         55407
# Attack     63201
# Defense    59074
# Sp. Atk    58256
# Sp. Def    57522
# Speed      54622
# dtype: int64

# %%
df.iloc[:, 4:10].sum(axis=1)
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Length: 800, dtype: int64

# %%
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype=object)

# %%
cols[:-1]
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation'], dtype=object)

# %%
df[[cols[-1]] + cols[:-1]]
# Out:
#      Legendary    #                   Name   Type 1  Type 2  HP  Attack  \
# 0        False    1              Bulbasaur    Grass  Poison  45      49
# 1        False    2                Ivysaur    Grass  Poison  60      62
# 2        False    3               Venusaur    Grass  Poison  80      82
# 3        False    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4        False    4             Charmander     Fire     NaN  39      52
# ..         ...  ...                    ...      ...     ...  ..     ...
# 795       True  719                Diancie     Rock   Fairy  50     100
# 796       True  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797       True  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798       True  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799       True  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0         49       65       65     45           1
# ...

# %%
df[cols[:-1]]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 0         65       65     45           1
# 1         80       80     60           1
# ...

# %%
df[cols[-1:] + cols[:-1]]
# Out:
#      Legendary    #                   Name   Type 1  Type 2  HP  Attack  \
# 0        False    1              Bulbasaur    Grass  Poison  45      49
# 1        False    2                Ivysaur    Grass  Poison  60      62
# 2        False    3               Venusaur    Grass  Poison  80      82
# 3        False    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4        False    4             Charmander     Fire     NaN  39      52
# ..         ...  ...                    ...      ...     ...  ..     ...
# 795       True  719                Diancie     Rock   Fairy  50     100
# 796       True  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797       True  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798       True  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799       True  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0         49       65       65     45           1
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  795     True
#  796     True
#  797     True
#  798     True
#  799     True
#  Name: Legendary, Length: 800, dtype: bool,
#         #                   Name   Type 1  Type 2  HP  Attack  Defense  \
#  0      1              Bulbasaur    Grass  Poison  45      49       49
#  1      2                Ivysaur    Grass  Poison  60      62       63
#  2      3               Venusaur    Grass  Poison  80      82       83
#  3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
#  4      4             Charmander     Fire     NaN  39      52       43
#  ..   ...                    ...      ...     ...  ..     ...      ...
#  795  719                Diancie     Rock   Fairy  50     100      150
#  796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
#  797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# ...

# %%
df.to_csv("mofidied.csv")

# %%
df.to_csv("mofidied.csv", index=False)

# %%
df.loc[(df['HP'] > 98) & (df['Attack'] < 20)]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113  Chansey  Normal    NaN  250       5        5       35      105
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
# 488  440  Happiny  Normal    NaN  100       5        5       15       65
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False
# 488     30           4      False

# %%
df.loc[(df['HP'] > 98) | (df['Attack'] < 20)]
# Out:
#        #              Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 44    39        Jigglypuff  Normal   Fairy  115      45       20       45
# 45    40        Wigglytuff  Normal   Fairy  140      70       45       85
# 96    89               Muk  Poison     NaN  105     105       75       65
# 120  112            Rhydon  Ground    Rock  105     130      120       45
# 121  113           Chansey  Normal     NaN  250       5        5       35
# ..   ...               ...     ...     ...  ...     ...      ...      ...
# 753  683        Aromatisse   Fairy     NaN  101      72       72       99
# 769  699           Aurorus    Rock     Ice  123      77       72       99
# 792  716           Xerneas   Fairy     NaN  126     131       95      131
# 793  717           Yveltal    Dark  Flying  126     131       95      131
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['HP']>198, 'Legendary'] = False

# %%
df.loc[df['HP']>198]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113  Chansey  Normal    NaN  250       5        5       35      105
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False
