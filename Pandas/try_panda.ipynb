# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df = pd.read_excel('pokemon_data.xlsx')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df = pd.read_csv('pokemon_data.txt', sep='\t')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.Name, df.HP, df.Speed
# Out:
# (0                  Bulbasaur
#  1                    Ivysaur
#  2                   Venusaur
#  3      VenusaurMega Venusaur
#  4                 Charmander
#                 ...
#  795                  Diancie
#  796      DiancieMega Diancie
#  797      HoopaHoopa Confined
#  798       HoopaHoopa Unbound
#  799                Volcanion
#  Name: Name, Length: 800, dtype: object,
#  0      45
#  1      60
#  2      80
#  3      80
#  4      39
#         ..
#  795    50
#  796    50
#  797    80
#  798    80
#  799    80
#  Name: HP, Length: 800, dtype: int64,
#  0       45
#  1       60
#  2       80
#  3       80
#  4       65
#        ...
#  795     50
#  796    110
#  797     70
#  798     80
#  799     70
#  Name: Speed, Length: 800, dtype: int64)

# %%
df[['Name', 'HP', 'Speed']]
# Out:
#                       Name  HP  Speed
# 0                Bulbasaur  45     45
# 1                  Ivysaur  60     60
# 2                 Venusaur  80     80
# 3    VenusaurMega Venusaur  80     80
# 4               Charmander  39     65
# ..                     ...  ..    ...
# 795                Diancie  50     50
# 796    DiancieMega Diancie  50    110
# 797    HoopaHoopa Confined  80     70
# 798     HoopaHoopa Unbound  80     80
# 799              Volcanion  80     70
#
# [800 rows x 3 columns]

# %%
df[['Name', 'HP', 'Speed']][:5]
# Out:
#                     Name  HP  Speed
# 0              Bulbasaur  45     45
# 1                Ivysaur  60     60
# 2               Venusaur  80     80
# 3  VenusaurMega Venusaur  80     80
# 4             Charmander  39     65

# %%
df[['Name', 'HP', 'Speed']][5:]
# Out:
#                           Name  HP  Speed
# 5                   Charmeleon  58     80
# 6                    Charizard  78    100
# 7    CharizardMega Charizard X  78    100
# 8    CharizardMega Charizard Y  78    100
# 9                     Squirtle  44     43
# ..                         ...  ..    ...
# 795                    Diancie  50     50
# 796        DiancieMega Diancie  50    110
# 797        HoopaHoopa Confined  80     70
# 798         HoopaHoopa Unbound  80     80
# 799                  Volcanion  80     70
#
# [795 rows x 3 columns]

# %%
df[['Name', 'HP', 'Speed']][-5:]
# Out:
#                     Name  HP  Speed
# 795              Diancie  50     50
# 796  DiancieMega Diancie  50    110
# 797  HoopaHoopa Confined  80     70
# 798   HoopaHoopa Unbound  80     80
# 799            Volcanion  80     70

# %%
df.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df.iloc[:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[2,4] , df.iloc[2,8]
# Out:
# (80, 100)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype=object)

# %%
df.columns.values[3]
# Out:
# 'Type 2'

# %%
list(df.columns.values)
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
import pandas as pd

student_dict = {'Name': ['Kate', 'Harry', 'Sheila'], 'Age': [10, 11, 12], 'Marks': [85, 77, 91]}

# create DataFrame from dict
student_df = pd.DataFrame(student_dict)
print(student_df)

# set index using column
student_df = student_df.set_index(['Name', 'Marks'])
print(student_df)
# Out:
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   11     77
# 2  Sheila   12     91
#               Age
# Name   Marks
# Kate   85      10
# Harry  77      11
# Sheila 91      12

# %%
len(student_df.index)
# Out:
# 3

# %%
import pandas as pd

student_dict = {'Name': ['Kate', 'Harry', 'Sheila'], 'Age': [10, 14, 12], 'Marks': [85, 77, 91]}

# create DataFrame from dict
df1 = pd.DataFrame(student_dict)
print(df1)

dict = {'Name':['Amy', 'Maddy'],
        'Age':[19, 12],
        'Marks':[93, 81]
       }
df2 = pd.DataFrame(dict)
print(df2)
df3 = pd.concat([df1, df2], ignore_index = True)

print(df3)
# Out:
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   14     77
# 2  Sheila   12     91
#     Name  Age  Marks
# 0    Amy   19     93
# 1  Maddy   12     81
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   14     77
# 2  Sheila   12     91
# 3     Amy   19     93
# 4   Maddy   12     81

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.columns[2:4]
df.columns[2]
# Out:
# 'Type 1'

# %%
list(df.columns)
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
    df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1 = df.iloc[:,:4] + df.iloc[:,:-1] + df.iloc[:,5:8]
df1
# Out:
#       #  Attack  Defense  Generation  HP  Name  Sp. Atk  Sp. Def  Speed  \
# 0   NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 1   NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 2   NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 3   NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 4   NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# ..   ..     ...      ...         ...  ..   ...      ...      ...    ...
# 795 NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 796 NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 797 NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 798 NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
# 799 NaN     NaN      NaN         NaN NaN   NaN      NaN      NaN    NaN
#
#      Type 1  Type 2
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# ...

# %%
df[:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df[:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.iloc[:,:4]
# Out:
#        #                   Name   Type 1  Type 2
# 0      1              Bulbasaur    Grass  Poison
# 1      2                Ivysaur    Grass  Poison
# 2      3               Venusaur    Grass  Poison
# 3      3  VenusaurMega Venusaur    Grass  Poison
# 4      4             Charmander     Fire     NaN
# ..   ...                    ...      ...     ...
# 795  719                Diancie     Rock   Fairy
# 796  719    DiancieMega Diancie     Rock   Fairy
# 797  720    HoopaHoopa Confined  Psychic   Ghost
# 798  720     HoopaHoopa Unbound  Psychic    Dark
# 799  721              Volcanion     Fire   Water
#
# [800 rows x 4 columns]

# %%
df[['Type 1', 'Name']]
# Out:
#       Type 1                   Name
# 0      Grass              Bulbasaur
# 1      Grass                Ivysaur
# 2      Grass               Venusaur
# 3      Grass  VenusaurMega Venusaur
# 4       Fire             Charmander
# ..       ...                    ...
# 795     Rock                Diancie
# 796     Rock    DiancieMega Diancie
# 797  Psychic    HoopaHoopa Confined
# 798  Psychic     HoopaHoopa Unbound
# 799     Fire              Volcanion
#
# [800 rows x 2 columns]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.sort_values(['Type 2', 'Attack'], ascending=[True, 0])
# Out:
#        #                     Name   Type 1 Type 2   HP  Attack  Defense  \
# 380  348                  Armaldo     Rock    Bug   75     125      100
# 379  347                  Anorith     Rock    Bug   45      95       50
# 501  451                  Skorupi   Poison    Bug   40      50       90
# 268  248  TyranitarMega Tyranitar     Rock   Dark  100     164      150
# 798  720       HoopaHoopa Unbound  Psychic   Dark   80     160       60
# ..   ...                      ...      ...    ...  ...     ...      ...
# 381  349                   Feebas    Water    NaN   20      15       20
# 139  129                 Magikarp    Water    NaN   20      10       55
# 261  242                  Blissey   Normal    NaN  255      10       10
# 121  113                  Chansey   Normal    NaN  250       5        5
# 488  440                  Happiny   Normal    NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
